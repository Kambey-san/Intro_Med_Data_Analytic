# %% [markdown]
# <a href="https://colab.research.google.com/github/Kambey-san/Intro_Med_Data_Analytic/blob/HW_lesson_01/KAA_IMD_HW_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Введение в анализ данных в медицине
# ### Урок 1. Обзор профессии и вакансии/ ДЗ
#
# Для одной профессии на стыке медицины и анализа данных найти 5 вакансий уровня middle, составить список требуемых компетенций и сопоставить с вашими приобретенными за время в GeekBrains компетенциями или имеющимися ранее.

# %% [markdown]
# ### Industry: clinical medicine, scientific medicine, pharmacies, clinical research

# %% [markdown]
# ### Position: Data science

# %% [markdown]
# Links:
#
# 1) <a href='https://domodedovo.hh.ru/vacancy/91556384?query=Data+science+%D0%B2+%D0%BC%D0%B5%D0%B4%D0%B8%D1%86%D0%B8%D0%BD%D0%B5&hhtmFrom=vacancy_search_list'>Специалист Data Science</a>.
#
# 2) <a href='https://getmatch.ru/vacancies/4476-data-scientist'>Data Scientist</a>.
#
# 3) <a href='https://domodedovo.hh.ru/vacancy/90247743'>Аналитик (Медицина)</a>.
#
# 4) <a href='https://domodedovo.hh.ru/vacancy/93771724?hhtmFrom=vacancy_search_list'>Middle devops engineer/DevOps инженер</a>.
#
# 5) <a href='https://domodedovo.hh.ru/vacancy/54738403'>Data Scientist (в медицине)</a>.

# %%
import pandas as pd

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
link = 'https://docs.google.com/spreadsheets/d/1UwFFo9CsoAXLoedIMdtDRaaVMYr2zm3a/edit?usp=drive_link&ouid=113870476829648524904&rtpof=true&sd=true'

id_test = link.split("/")[-2]

downloaded = drive.CreateFile({'id':id_test})
downloaded.GetContentFile('Requirements.xlsx')

# %%
df = pd.read_excel('Requirements.xlsx')

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#                                          Requirements Competence
# 0   Опыт работы в проектах, связанных с производст...        Yes
# 1   Умение работать как самостоятельно, так и упра...        Yes
# 2   Умение понятным «бизнес-языком» описать получе...        Yes
# 3   Высшее образование в области «Математика» или ...         No
# 4                                          Знание SQL        Yes
# 5                    Топовое техническое образование.         No
# 6            Опыт от 1 года в области анализа данных.        Yes
# 7   Знание теории вероятностей, математической ста...        Yes
# 8   Знание Python (NumPy, SciPy, Pandas, Scikit-le...        Yes
# 9                  Общая алгоритмическая грамотность.        Yes
# 10  Релевантный опыт в медицинской, желательно ком...        Yes
# 11     Понимание основных бизнес-процессов в медицине        Yes
# 12  Навыки проведения комплексного коммерческого а...        Yes
# ...
